# %% [markdown]
# <a href="https://colab.research.google.com/github/bacdam91/Introduction-to-Machine-Learning-on-Google-Colab/blob/master/Introduction_to_Machine_Learning_on_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 					<li data-target="#presentation" data-slide-to="2"></li>
# 					<li data-target="#presentation" data-slide-to="3"></li>
# 					<li data-target="#presentation" data-slide-to="4"></li>
# 					<li data-target="#presentation" data-slide-to="5"></li>
# 					<li data-target="#presentation" data-slide-to="6"></li>
# 					<li data-target="#presentation" data-slide-to="7"></li>
# 					<li data-target="#presentation" data-slide-to="8"></li>
# 					<li data-target="#presentation" data-slide-to="9"></li>
# 					<li data-target="#presentation" data-slide-to="10"></li>
# 					<li data-target="#presentation" data-slide-to="11"></li>
# 					<li data-target="#presentation" data-slide-to="12"></li>
# 					<li data-target="#presentation" data-slide-to="13"></li>
# 					<li data-target="#presentation" data-slide-to="14"></li>
# 					<li data-target="#presentation" data-slide-to="15"></li>
# 					<li data-target="#presentation" data-slide-to="16"></li>
# 					<li data-target="#presentation" data-slide-to="17"></li>
# 					<li data-target="#presentation" data-slide-to="18"></li>
# 					<li data-target="#presentation" data-slide-to="19"></li>
# 					<li data-target="#presentation" data-slide-to="20"></li>
# 					<li data-target="#presentation" data-slide-to="21"></li>
# 					<li data-target="#presentation" data-slide-to="22"></li>
# 					<li data-target="#presentation" data-slide-to="23"></li>
# 					<li data-target="#presentation" data-slide-to="24"></li>
# 					<li data-target="#presentation" data-slide-to="25"></li>
# 					<li data-target="#presentation" data-slide-to="26"></li>
# 					<li data-target="#presentation" data-slide-to="27"></li>
# 					<li data-target="#presentation" data-slide-to="28"></li>
# 					<li data-target="#presentation" data-slide-to="29"></li>
# 					<li data-target="#presentation" data-slide-to="30"></li>
# 					<li data-target="#presentation" data-slide-to="31"></li>
# 					<li data-target="#presentation" data-slide-to="32"></li>
# 					<li data-target="#presentation" data-slide-to="33"></li>
# 					<li data-target="#presentation" data-slide-to="34"></li>
# 					<li data-target="#presentation" data-slide-to="35"></li>
# 					<li data-target="#presentation" data-slide-to="36"></li>
# 					<li data-target="#presentation" data-slide-to="37"></li>
# 					<li data-target="#presentation" data-slide-to="38"></li>
# 					<li data-target="#presentation" data-slide-to="39"></li>
# 					<li data-target="#presentation" data-slide-to="40"></li>
# 					<li data-target="#presentation" data-slide-to="41"></li>
# 					<li data-target="#presentation" data-slide-to="42"></li>
# 					<li data-target="#presentation" data-slide-to="43"></li>
# 					<li data-target="#presentation" data-slide-to="44"></li>
# 					<li data-target="#presentation" data-slide-to="45"></li>
# 					<li data-target="#presentation" data-slide-to="46"></li>
# 					<li data-target="#presentation" data-slide-to="47"></li>
# 					<li data-target="#presentation" data-slide-to="48"></li>
# 					<li data-target="#presentation" data-slide-to="49"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Introduction to Machine Learning</strong
# 								>
# 							</h1>
# 							<h4><strong>on Google Colab</strong></h4>
# 							<h6 class="dbs-subtitle dbs-separate">
# 								By Bac Trach Dam
# 							</h6>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Who is this talk for?</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<p>
# 									Anyone who is interested in
# 									<strong>Artificial Intelligence</strong> and
# 									<strong>Machine Learning</strong>
# 								</p>
# 								<ul>
# 									<li>From any profession</li>
# 									<li>Of any age</li>
# 									<li>
# 										With any level of ML knowledge (but
# 										mainly newcomers)
# 									</li>
# 								</ul>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Talk breakdown</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<ol>
# 									<li>Introduction</li>
# 									<li>The "Fun"damentals</li>
# 									<li>
# 										Building a simple Neural Network (NN)
# 									</li>
# 									<li>Q&A's</li>
# 								</ol>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>INTRODUCTION</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>A little bit about me</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<ul>
# 									<li>Bac Trach Dam</li>
# 									<li>
# 										Bachelor of Pharmacy - Pharmacist
# 										(Part-time)
# 									</li>
# 									<li>
# 										<div>
# 											Study at Swinburne University of
# 											Technology
# 											<ul>
# 												<li>Research assistance</li>
# 												<li>
# 													Third-Party Library
# 													Recommender System using
# 													Convolutional Graph Neural
# 													Network
# 												</li>
# 											</ul>
# 										</div>
# 									</li>
# 									<li>
# 										<div>
# 											Front-end developer at a Medical
# 											start-up
# 											<ul>
# 												<li>NodeJs</li>
# 												<li>ReactJs</li>
# 												<li>Material-UI</li>
# 												<li>AWS</li>
# 											</ul>
# 										</div>
# 									</li>
# 								</ul>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Artificial Intelligence vs. Machine
# 									Learning</strong
# 								>
# 							</h1>
# 							<div class="dbs-standard">
# 								<ul>
# 									<li>
# 										AI is a concept/feature within a system
# 									</li>
# 									<li>
# 										<div>
# 											ML is the implementation that gives
# 											a system the AI capabilities
# 											<ul>
# 												<li>Involves Data Science</li>
# 												<li>
# 													<div>
# 														Advancing field because:
# 														<ul>
# 															<li>
# 																Computing power
# 																of modern
# 																hardward
# 															</li>
# 															<li>
# 																Massive data
# 																warehouses
# 															</li>
# 														</ul>
# 													</div>
# 												</li>
# 											</ul>
# 										</div>
# 									</li>
# 								</ul>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://cdn.vox-cdn.com/thumbor/CMJs1AJyAmf27RUd2UI5WBSZpy4=/0x0:3049x2048/920x613/filters:focal(1333x1562:1819x2048):format(webp)/cdn.vox-cdn.com/uploads/chorus_image/image/63058104/fake_ai_faces.0.png"
# 								alt="This person does not exist."
# 								class="dbs-image"
# 							/>
# 							<a
# 								href="http://www.thispersondoesnotexist.com"
# 								class="dbs-caption"
# 								>These people do not exist.</a
# 							>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://techcrunch.com/wp-content/uploads/2019/03/NVIDIA-GauGAN-AI-demo-screenshot.jpg?w=730&crop=1"
# 								alt="AI Waterfall"
# 								class="dbs-image"
# 							/>
# 							<a
# 								href="https://techcrunch.com/2019/03/18/nvidia-ai-turns-sketches-into-photorealistic-landscapes-in-seconds/"
# 								class="dbs-caption"
# 								>This waterfall does not exist.</a
# 							>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://miro.medium.com/max/998/1*9PgbXL8NYzZ0kfCwmdBlEA.gif"
# 								alt="Amy Cages"
# 							/>
# 							<a
# 								href="https://miro.medium.com/max/998/1*9PgbXL8NYzZ0kfCwmdBlEA.gif"
# 								class="dbs-caption"
# 								>Swapping faces.</a
# 							>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://miro.medium.com/max/998/1*teA4d0RQ38ceNZoVqbRvvQ.gif"
# 								alt="Russian meddling."
# 							/>
# 							<a
# 								href="https://towardsdatascience.com/ethics-in-generative-ai-detecting-fake-videos-93b69fcbabc7"
# 								class="dbs-caption"
# 								>2016 US election</a
# 							>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://miro.medium.com/max/998/1*fXRznlKhiz0fASHy2ioMtg.gif"
# 								alt="Russian meddling."
# 							/>
# 							<a
# 								href="https://towardsdatascience.com/ethics-in-generative-ai-detecting-fake-videos-93b69fcbabc7"
# 								class="dbs-caption"
# 								><q>Put the bunny back in the box.</q></a
# 							>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>More applications of ML</strong>
# 							</h1>
# 							<div class="dbs-row dbs-standard dbs-fluid">
# 								<ul>
# 									<li>Voice manipulation/cloning</li>
# 									<li>Aiding medical diagnosis</li>
# 									<li>Generating text/novels</li>
# 									<li>Physics simulation</li>
# 									<li>(Competitive) gaming</li>
# 									<li>Object detection</li>
# 									<li>Facial recognition</li>
# 								</ul>
# 								<ul>
# 									<li>Recommender system</li>
# 									<li>Movement tracking</li>
# 									<li>Fraud detection</li>
# 									<li>Natural Language Processing</li>
# 									<li>Virtual assistant</li>
# 									<li>Articles/videos summarisation</li>
# 									<li>Painting/Art</li>
# 								</ul>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>THE "FUN"DAMENTALS</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h6 class="dbs-secondary">
# 								The fundamentals of ML
# 							</h6>
# 							<h1>
# 								<strong>Two types of ML problems</strong>
# 							</h1>
# 							<table class="dbs-standard">
# 								<thead>
# 									<tr>
# 										<th>Problem types</th>
# 										<th>Problem defintions</th>
# 										<th>Problem examples</th>
# 									</tr>
# 								</thead>
# 								<tbody>
# 									<tr>
# 										<td>
# 											<strong>REGRESSION</strong>
# 										</td>
# 										<td>
# 											Predicting a value from a continuum
# 										</td>
# 										<td>
# 											What is the price of a property?
# 										</td>
# 									</tr>
# 									<tr>
# 										<td><strong>CLASSIFICATION</strong></td>
# 										<td>
# 											Assigning a discreet class from a
# 											number of classes
# 										</td>
# 										<td>
# 											Is this a cat or a dog?
# 										</td>
# 									</tr>
# 								</tbody>
# 							</table>
# 							<p class="dbs-subtitle dbs-standard">
# 								The type of ML problem can be determined by how
# 								the problem is defined.
# 							</p>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>How to do ML?</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<ol>
# 									<li>Collect data</li>
# 									<li>Prepare data</li>
# 									<li>Build model</li>
# 									<li>Train model</li>
# 									<li>Predict with model</li>
# 									<li>Finetune model</li>
# 								</ol>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Exchange rate of AUDNZD over time
# 								</strong>
# 							</h1>
# 							<table id="dbs-forex-table" class="dbs-standard">
# 								<thead>
# 									<tr>
# 										<th>AUD <br />\((x)\)</th>
# 										<th>NZD <br />\((y)\)</th>
# 									</tr>
# 								</thead>
# 								<tbody>
# 									<tr>
# 										<td>0</td>
# 										<td>0</td>
# 									</tr>
# 									<tr>
# 										<td>1</td>
# 										<td>1.2</td>
# 									</tr>
# 									<tr>
# 										<td>2</td>
# 										<td>1.8</td>
# 									</tr>
# 									<tr>
# 										<td>3</td>
# 										<td>2.6</td>
# 									</tr>
# 									<tr>
# 										<td>4</td>
# 										<td>3.8</td>
# 									</tr>
# 									<tr>
# 										<td>5</td>
# 										<td>5.2</td>
# 									</tr>
# 									<tr>
# 										<td>6</td>
# 										<td>6.1</td>
# 									</tr>
# 									<tr>
# 										<td>7</td>
# 										<td>7.5</td>
# 									</tr>
# 									<tr>
# 										<td>8</td>
# 										<td>8</td>
# 									</tr>
# 									<tr>
# 										<td>9</td>
# 										<td>8.8</td>
# 									</tr>
# 								</tbody>
# 							</table>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>The Nomeclature</strong>
# 							</h1>
# 							<img
# 								src="https://drive.google.com/uc?id=15jqXQLSg9XLMiO7l_ZFLJc6NEMI0zYTU"
# 								alt="The Gnome"
# 								class="dbs-small-img dbs-standard"
# 							/>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>The Nomeclature</strong>
# 							</h1>
# 							<table class="dbs-standard">
# 								<thead>
# 									<tr>
# 										<th>Symbols</th>
# 										<th>Meaning</th>
# 									</tr>
# 								</thead>
# 								<tbody>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(y\)
# 											</span>
# 										</td>
# 										<td>
# 											Label
# 										</td>
# 									</tr>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(y'\)
# 											</span>
# 										</td>
# 										<td>
# 											Prediction
# 										</td>
# 									</tr>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(\theta\)
# 											</span>
# 										</td>
# 										<td>
# 											Weight tensor
# 										</td>
# 									</tr>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(X\)
# 											</span>
# 										</td>
# 										<td>
# 											A sample (Row in the dataset)
# 										</td>
# 									</tr>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(x_i\)
# 											</span>
# 										</td>
# 										<td>
# 											An attribute (Column in the dataset)
# 										</td>
# 									</tr>
# 									<tr>
# 										<td>
# 											<span class="math">
# 												\(b\)
# 											</span>
# 										</td>
# 										<td>
# 											Bias
# 										</td>
# 									</tr>
# 								</tbody>
# 							</table>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Model = Algorithm = Neural Network</strong
# 								>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Tensor = Matrix = Multi-dimensional
# 									array</strong
# 								>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Exchange rate of AUDNZD over time</strong
# 								>
# 							</h1>
# 							<table id="dbs-forex-table" class="dbs-standard">
# 								<thead>
# 									<tr>
# 										<th>AUD <br />\((x)\)</th>
# 										<th>NZD <br />\((y)\)</th>
# 									</tr>
# 								</thead>
# 								<tbody>
# 									<tr>
# 										<td>0</td>
# 										<td>0</td>
# 									</tr>
# 									<tr>
# 										<td>1</td>
# 										<td>1.2</td>
# 									</tr>
# 									<tr>
# 										<td>2</td>
# 										<td>1.8</td>
# 									</tr>
# 									<tr>
# 										<td>3</td>
# 										<td>2.6</td>
# 									</tr>
# 									<tr>
# 										<td>4</td>
# 										<td>3.8</td>
# 									</tr>
# 									<tr>
# 										<td>5</td>
# 										<td>5.2</td>
# 									</tr>
# 									<tr>
# 										<td>6</td>
# 										<td>6.1</td>
# 									</tr>
# 									<tr>
# 										<td>7</td>
# 										<td>7.5</td>
# 									</tr>
# 									<tr>
# 										<td>8</td>
# 										<td>8</td>
# 									</tr>
# 									<tr>
# 										<td>9</td>
# 										<td>8.8</td>
# 									</tr>
# 								</tbody>
# 							</table>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Exploring the data </strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<img
# 									src="https://drive.google.com/uc?id=1749ehO39Ay4X7IwFb_nMS3FOQ8JWdl4o"
# 									alt="Exploring the data"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Our intuition (hypothesis)</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<img
# 									src="https://drive.google.com/uc?id=1L0RuLG4O5L5PlIhuXcb9Y3X3I337dmnG"
# 									alt="Exploring the data"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>
# 									Our intuition (hypothesis)
# 								</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<h6 class="dbs-secondary">Linear equation</h6>
# 								<h1>
# 									\(y = mx + c\)
# 								</h1>
# 							</div>
# 							<div class="dbs-standard">
# 								<h6 class="dbs-secondary">Our hypothesis</h6>
# 								<h1>
# 									\(y' = \theta X + b\)
# 								</h1>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h6 class="dbs-secondary">
# 								How and where do we start?
# 							</h6>
# 							<h1>
# 								<strong>Take a guess (Initialisation)!</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>A guess</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(0\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<img
# 									src="https://drive.google.com/uc?id=1KZ8L_C1dTjwIJOp-hCPgNReHzgXeZ5M1"
# 									alt="Parameter initialisation"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Then what?</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Another guess</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(0\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<img
# 									src="https://drive.google.com/uc?id=1XGBuLnhSAvNj62D0jj1Q6w26wOd0A2dC"
# 									alt="Parameter initialisation"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Another-nother guess</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(-2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<img
# 									src="https://drive.google.com/uc?id=1WoNCZgYLhRagj2c27OKJ7k49-M6ukP_y"
# 									alt="Parameter initialisation"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Another-nother-nother guess</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<img
# 									src="https://drive.google.com/uc?id=1rjEMXXkkLlQwVbsZBBYYP4fQ5IYAH5Qy"
# 									alt="Parameter initialisation"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Not very intelligent...</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<img
# 									src="https://drive.google.com/uc?id=1YHIBRY9CXd6wOVRl_jAxElP5mUZSRb9e"
# 									alt="Waiting..."
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://drive.google.com/uc?id=1eoHqMzCrbdF3w2ML0CDOoTkjBVbwhCx6"
# 								alt="Errors everywhere"
# 							/>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Connect the dots</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<img
# 									src="https://drive.google.com/uc?id=1NlBpOH81x61f_b86XX0AgsUCdQcXx5eL"
# 									alt="Errors"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1><strong>Error (loss) function</strong></h1>
# 							<div class="dbs-standard">
# 								<span class="math lg">
# 									\(RMSE = \sqrt{\frac{1}{n}\sum^{n}_{i=1}(y_i
# 									- y'_i)^2}\)
# 								</span>
# 							</div>
# 							<h3 class="dbs-subtitle dbs-standard">
# 								Root Mean Square Error
# 							</h3>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>Seems complex... Let's break it
# 									down.</strong
# 								>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error (loss) function: Part 1</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<span class="math lg">
# 									\((y_i - y'_i)^2\)
# 								</span>
# 							</div>
# 							<h3 class="dbs-subtitle dbs-standard">
# 								Square Error
# 							</h3>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>
# 									Our intuition (hypothesis)
# 								</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<h6 class="dbs-secondary">Linear equation</h6>
# 								<h1>
# 									\(y = mx + c\)
# 								</h1>
# 							</div>
# 							<div class="dbs-standard">
# 								<h6 class="dbs-secondary">Our hypothesis</h6>
# 								<h1>
# 									\(y' = \theta X + b\)
# 								</h1>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error (loss) function: Part 1a</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<table id="dbs-forex-table" class="dbs-skinny">
# 									<thead>
# 										<tr>
# 											<th>AUD <br />\((x)\)</th>
# 											<th>NZD <br />\((y)\)</th>
# 											<th>Prediction <br />\((y')\)</th>
# 											<th>
# 												Error <br />\((y_i - y'_i)\)
# 											</th>
# 											<th>
# 												Square Error <br />\((y_i -
# 												y'_i)^2\)
# 											</th>
# 										</tr>
# 									</thead>
# 									<tbody>
# 										<tr>
# 											<td>0</td>
# 											<td>0</td>
# 											<td>-3</td>
# 											<td>3</td>
# 											<td>9</td>
# 										</tr>
# 										<tr>
# 											<td>1</td>
# 											<td>1.2</td>
# 											<td>-1</td>
# 											<td>2.2</td>
# 											<td>4.84</td>
# 										</tr>
# 										<tr>
# 											<td>2</td>
# 											<td>1.8</td>
# 											<td>1</td>
# 											<td>0.8</td>
# 											<td>0.64</td>
# 										</tr>
# 										<tr>
# 											<td>3</td>
# 											<td>2.6</td>
# 											<td>3</td>
# 											<td>-0.4</td>
# 											<td>0.16</td>
# 										</tr>
# 										<tr>
# 											<td>4</td>
# 											<td>3.8</td>
# 											<td>5</td>
# 											<td>-1.2</td>
# 											<td>1.44</td>
# 										</tr>
# 										<tr>
# 											<td>5</td>
# 											<td>5.2</td>
# 											<td>7</td>
# 											<td>-1.8</td>
# 											<td>3.24</td>
# 										</tr>
# 										<tr>
# 											<td>6</td>
# 											<td>6.1</td>
# 											<td>9</td>
# 											<td>-2.9</td>
# 											<td>8.41</td>
# 										</tr>
# 										<tr>
# 											<td>7</td>
# 											<td>7.5</td>
# 											<td>11</td>
# 											<td>-3.5</td>
# 											<td>12.25</td>
# 										</tr>
# 										<tr>
# 											<td>8</td>
# 											<td>8</td>
# 											<td>13</td>
# 											<td>-5</td>
# 											<td>25</td>
# 										</tr>
# 										<tr>
# 											<td>9</td>
# 											<td>8.8</td>
# 											<td>15</td>
# 											<td>-6.2</td>
# 											<td>38.44</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error (loss) function: Part 2</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<span class="math lg">
# 									\(\sum^{n}_{i=1}(y_i - y'_i)^2\)
# 								</span>
# 							</div>
# 							<h3 class="dbs-subtitle dbs-standard">
# 								Sum of Square Error
# 							</h3>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error (loss) function: Part 2</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 								<table id="dbs-forex-table" class="dbs-skinny">
# 									<thead>
# 										<tr>
# 											<th>AUD <br />\((x)\)</th>
# 											<th>NZD <br />\((y)\)</th>
# 											<th>Prediction <br />\((y')\)</th>
# 											<th>
# 												Error <br />\((y_i - y'_i)\)
# 											</th>
# 											<th>
# 												Square Error <br />\((y_i -
# 												y'_i)^2\)
# 											</th>
# 										</tr>
# 									</thead>
# 									<tbody>
# 										<tr>
# 											<td>0</td>
# 											<td>0</td>
# 											<td>-3</td>
# 											<td>3</td>
# 											<td>9</td>
# 										</tr>
# 										<tr>
# 											<td>1</td>
# 											<td>1.2</td>
# 											<td>-1</td>
# 											<td>2.2</td>
# 											<td>4.84</td>
# 										</tr>
# 										<tr>
# 											<td>2</td>
# 											<td>1.8</td>
# 											<td>1</td>
# 											<td>0.8</td>
# 											<td>0.64</td>
# 										</tr>
# 										<tr>
# 											<td>3</td>
# 											<td>2.6</td>
# 											<td>3</td>
# 											<td>-0.4</td>
# 											<td>0.16</td>
# 										</tr>
# 										<tr>
# 											<td>4</td>
# 											<td>3.8</td>
# 											<td>5</td>
# 											<td>-1.2</td>
# 											<td>1.44</td>
# 										</tr>
# 										<tr>
# 											<td>5</td>
# 											<td>5.2</td>
# 											<td>7</td>
# 											<td>-1.8</td>
# 											<td>3.24</td>
# 										</tr>
# 										<tr>
# 											<td>6</td>
# 											<td>6.1</td>
# 											<td>9</td>
# 											<td>-2.9</td>
# 											<td>8.41</td>
# 										</tr>
# 										<tr>
# 											<td>7</td>
# 											<td>7.5</td>
# 											<td>11</td>
# 											<td>-3.5</td>
# 											<td>12.25</td>
# 										</tr>
# 										<tr>
# 											<td>8</td>
# 											<td>8</td>
# 											<td>13</td>
# 											<td>-5</td>
# 											<td>25</td>
# 										</tr>
# 										<tr>
# 											<td>9</td>
# 											<td>8.8</td>
# 											<td>15</td>
# 											<td>-6.2</td>
# 											<td>38.44</td>
# 										</tr>
# 										<tr class="dbs-sum">
# 											<td colspan="4">
# 												<span>
# 													\(\sum^{n}_{i=1}(y_i -
# 													y'_i)^2\)
# 												</span>
# 											</td>
#
# 											<td>103.42</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Error (loss) function: Part 3</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<span class="math lg">
# 									\(\frac{1}{n}\sum^{n}_{i=1}(y_i - y'_i)^2 =
# 									\frac{103.42}{10} = 10.342\)
# 								</span>
# 							</div>
# 							<h3 class="dbs-subtitle dbs-standard">
# 								Mean Square Error
# 							</h3>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Error (loss) function: Part 4</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<span class="math md">
# 									\(RMSE = \sqrt{\frac{1}{n}\sum^{n}_{i=1}(y_i
# 									- y'_i)^2} = \sqrt{10.342} = 3.216 \)
# 								</span>
# 							</div>
# 							<h3 class="dbs-subtitle dbs-standard">
# 								Root Mean Square Error
# 							</h3>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error (loss) score</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<table>
# 									<tbody>
# 										<tr>
# 											<td>\(\theta\) (slope)</td>
# 											<td>\(2\)</td>
# 										</tr>
# 										<tr>
# 											<td>\(b\) (y-intercept)</td>
# 											<td>\(-3\)</td>
# 										</tr>
# 										<tr>
# 											<td>Error score</td>
# 											<td>\(3.216\)</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Rinse and repeat</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Error Graphs</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<img
# 									src="https://drive.google.com/uc?id=1Gg9k19yTfIrLVEVD2LY_y9KNd9Zti8bB"
# 									alt="Surface plot"
# 								/>
# 								<img
# 									src="https://drive.google.com/uc?id=1amR6nytMEd1F8uc4HiqCG7I6CgrO5ZRr"
# 									alt="Contour"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>CPU Intensive. Not possible.</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Gradient Descend</strong>
# 							</h1>
# 							<h4>
# 								<q>Just keep rolling</q>
# 							</h4>
# 							<div class="dbs-standard dbs-row dbs-fluid">
# 								<img
# 									src="https://drive.google.com/uc?id=1rfDM_b87_G1E2Hl2SOXvYU_-qHKStf8Z"
# 									alt="Ball on a hill"
# 								/>
# 								<img
# 									src="https://drive.google.com/uc?id=1gzF7FlqSIL1yrzmNjPShxUJ-Mgoc8-99"
# 									alt="Ball on the same hill"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h4 class="dbs-secondary">
# 								Calculate the slope at any point using
# 							</h4>
# 							<h1>
# 								<strong>Differential Calculus</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>DIFFERENTIAL CALCULUS</strong>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<img
# 								src="https://drive.google.com/uc?id=12jPun1hl6uJ4U9ecW_bjFi2u3UlvTXRa"
# 								alt="trolled"
# 							/>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 					<li data-target="#presentation" data-slide-to="2"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong
# 									>BUILDING A SIMPLE NEURAL NETWORK
# 									(NN)</strong
# 								>
# 							</h1>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>MXNet on Google Colab</strong>
# 							</h1>
# 							<img
# 								class="dbs-small-img dbs-standard"
# 								src="https://miro.medium.com/max/1200/1*Lb_b6AhCrH3Gq1HYYM0Fog.png"
# 								alt="MXNet logo"
# 							/>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong
# 									>Installing MXNet on Google Colab</strong
# 								>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# !pip install mxnet
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
# !pip install mxnet
# Out:
# ...
#      |████████████████████████████████| 68.7MB 55kB/s
# ...
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# ...

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Importing libraries</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# from mxnet import nd, gluon, autograd
# from mxnet.gluon import nn
# from mxnet.gluon.data.vision import datasets, transforms
# import matplotlib.pyplot as plt
# import time
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
from mxnet import nd, gluon, autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import datasets, transforms
import matplotlib.pyplot as plt
import time

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 					<li data-target="#presentation" data-slide-to="2"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Downloading the dataset</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# mnist_train = datasets.FashionMNIST(train=True)
# X, y = mnist_train[0]
# print("X shape: ", X.shape, "X dtype: ", X.dtype, "y: ", y)
#
# # Output: X shape:  (28, 28, 1) X dtype:  &lt;class 'numpy.uint8'&gt; y:  2
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<div class="dbs-standard">
# 								<h1>
# 									<strong>MNIST Fashion Dataset</strong>
# 								</h1>
# 								<div class="dbs-standard">
# 									<ul>
# 										<li>
# 											<div>
# 												Collection 70,000 images of
# 												clothing items
# 												<ul>
# 													<li>
# 														60,000 images are
# 														training
# 													</li>
# 													<li>
# 														10,000 images are
# 														testing/validation
# 													</li>
# 												</ul>
# 											</div>
# 										</li>
# 										<li>
# 											Each image is 28x28 pixels
# 										</li>
# 										<li>
# 											Categorised into 10 different groups
# 										</li>
# 									</ul>
# 									<div class="dbs-row">
# 										<ul>
# 											<li>0 = t-shirt</li>
# 											<li>1 = trouser</li>
# 											<li>2 = pullover</li>
# 											<li>3 = dress</li>
# 											<li>4 = coat</li>
# 										</ul>
# 										<ul>
# 											<li>5 = sandal</li>
# 											<li>6 = shirt</li>
# 											<li>7 = sneaker</li>
# 											<li>8 = bag</li>
# 											<li>9 = ankle boot</li>
# 										</ul>
# 									</div>
# 								</div>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Clothing labels</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# text_labels = [
# 				't-shirt', 'trouser', 'pullover', 'dress', 'coat',
# 				'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot'
# 			]
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
mnist_train = datasets.FashionMNIST(train=True)
X, y = mnist_train[0]

print("X shape: ", X.shape, "X dtype: ", X.dtype, "y: ", y)
# Out:
# ...
# X shape:  (28, 28, 1) X dtype:  <class 'numpy.uint8'> y:  2

# %%
text_labels = ['t-shirt', 'trouser', 'pullover', 'dress', 'coat',
               'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Exploring the dataset</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# X, y = mnist_train[0:10]
# # plot images
# fig, ax = plt.subplots(1, X.shape[0], figsize=(30, 30))
# for f, xi, yi in zip(ax, X, y):
#     # 3D->2D by removing the last channel dim
#     f.imshow(xi.reshape((28,28)).asnumpy())
#     f.set_title(text_labels[int(yi)])
# plt.show()
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
X, y = mnist_train[0:10]
# plot images
fig, ax = plt.subplots(1, X.shape[0], figsize=(30, 30))
for f, xi, yi in zip(ax, X, y):
    # 3D->2D by removing the last channel dim
    f.imshow(xi.reshape((28,28)).asnumpy())
    f.set_title(text_labels[int(yi)])
plt.show()

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 					<li data-target="#presentation" data-slide-to="2"></li>
# 					<li data-target="#presentation" data-slide-to="3"></li>
# 					<li data-target="#presentation" data-slide-to="4"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong
# 									>Transformers: Tensors normalised</strong
# 								>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# transformer = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize(0.13, 0.31)])
# mnist_train = mnist_train.transform_first(transformer)
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Batch please!</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# batch_size = 256
# train_data = gluon.data.DataLoader(
#     mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Batch please!</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# for data, label in train_data:
#     print(data.shape, label.shape)
#     break
#     #Output: (256, 1, 28, 28) (256,)
#
# print(len(train_data))
# #Output: 235
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>1, 2, 3, testing, testing.</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# mnist_valid = gluon.data.vision.FashionMNIST(train=False)
# valid_data = gluon.data.DataLoader(
#     mnist_valid.transform_first(transformer),
#     batch_size=batch_size, num_workers=4)
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>1, 2, 3, testing, testing.</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# for data, label in valid_data:
#     print(data.shape, label.shape)
#     break
#     #Output: (256, 1, 28, 28) (256,)
#
# print(len(valid_data))
# #Output: 40
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(0.13, 0.31)])
mnist_train = mnist_train.transform_first(transformer)

# %%
batch_size = 256
train_data = gluon.data.DataLoader(
    mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
for data, label in train_data:
    print(data.shape, label.shape)
    break

print(len(train_data))
# Out:
# (256, 1, 28, 28) (256,)
# 235

# %%
mnist_valid = gluon.data.vision.FashionMNIST(train=False)
valid_data = gluon.data.DataLoader(
    mnist_valid.transform_first(transformer),
    batch_size=batch_size, num_workers=4)

for data, label in valid_data:
    print(data.shape, label.shape)
    break
print(len(valid_data))
# Out:
# ...
# (256, 1, 28, 28) (256,)
# 40

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 					<li data-target="#presentation" data-slide-to="2"></li>
# 					<li data-target="#presentation" data-slide-to="3"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Skynet 1.0.0a</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# net = nn.Sequential()
# net.add(
#             nn.Dense(120, activation="relu"),
#             nn.Dense(84, activation="relu"),
#             nn.Dense(10)
#         )
# net.initialize()
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>The layers</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# net.collect_params()
#
# #Output:
# #   sequential1_ (
# #       Parameter dense3_weight (shape=(120, 0), dtype=float32)
# #       Parameter dense3_bias (shape=(120,), dtype=float32)
# #       Parameter dense4_weight (shape=(84, 0), dtype=float32)
# #       Parameter dense4_bias (shape=(84,), dtype=float32)
# #       Parameter dense5_weight (shape=(10, 0), dtype=float32)
# #       Parameter dense5_bias (shape=(10,), dtype=float32)
# #   )
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong
# 									>Loss function and gradient descend</strong
# 								>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
#
# trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.1})
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Accuracy metric</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# def acc(output, label):
#     # output: (batch, num_output) float32 ndarray
#     # label: (batch, ) int32 ndarray
#     score = (output.argmax(axis=1) == label.astype('float32')).mean().asscalar()
#     return score
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
net = nn.Sequential()
net.add(nn.Dense(120, activation="relu"),
        nn.Dense(84, activation="relu"),
        nn.Dense(10))
net.initialize()

# %%
net.collect_params()
# Out:
# sequential0_ (
#   Parameter dense0_weight (shape=(120, 0), dtype=float32)
#   Parameter dense0_bias (shape=(120,), dtype=float32)
#   Parameter dense1_weight (shape=(84, 0), dtype=float32)
#   Parameter dense1_bias (shape=(84,), dtype=float32)
#   Parameter dense2_weight (shape=(10, 0), dtype=float32)
#   Parameter dense2_bias (shape=(10,), dtype=float32)
# )

# %%
softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.1})

# %%
def acc(output, label):
    # output: (batch, num_output) float32 ndarray
    # label: (batch, ) int32 ndarray
    score = (output.argmax(axis=1) == label.astype('float32')).mean().asscalar()
    return score

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
#
# 		pre code.dbs-code-sm {
# 			font-size: 1.2rem;
# 		}
#
# 		.dbs-scroll {
# 			height: 500px;
# 			overflow-y: scroll;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Training day</strong>
# 							</h1>
# 							<div class="dbs-standard dbs-scroll">
# 								<pre>
# 								    <code class="language-python dbs-code">
# for epoch in range(20):
#     # Reset parameters
#     train_loss, train_acc, valid_acc = 0., 0., 0.
#
#     # start timer
#     tic = time.time()
#
#     # Training the network
#     for data, label in train_data:
#         # forward propagation
#         # autograd scope to record gradients
#         with autograd.record():
#
#             # Feeding the data into the network
#             output = net(data)
#
#             # calculate the loss (how big the error)
#             loss = softmax_cross_entropy(output, label)
#
#         #backward propagation
#         loss.backward()
#
#         # update parameters
#         trainer.step(batch_size)
#
#         # calculate training metrics
#         train_loss += loss.mean().asscalar()
#         train_acc += acc(output, label)
#
#     # calculate validation accuracy
#     for data, label in valid_data:
#         valid_acc += acc(net(data), label)
#
#     print("Epoch %d: loss %.3f, train acc %.3f, test acc %.3f, in %.1f sec" % (
#             (epoch + 1), train_loss/len(train_data), train_acc/len(train_data),
#             valid_acc/len(valid_data), time.time()-tic))
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
for epoch in range(20):
    # reset parameters
    train_loss, train_acc, valid_acc = 0., 0., 0.

    # start timer
    tic = time.time()
    
    # Training the network
    for data, label in train_data:
        # forward propagation
        # autograd scope to record gradients
        with autograd.record():

            # Feeding the data into the network
            output = net(data)

            # calculate the loss (how big the error)
            loss = softmax_cross_entropy(output, label)
        
        #backward propagation
        loss.backward()
        
        # update parameters
        trainer.step(batch_size)
        
        # calculate training metrics
        train_loss += loss.mean().asscalar()
        train_acc += acc(output, label)
        
    # calculate validation accuracy
    for data, label in valid_data:
        valid_acc += acc(net(data), label)

    print("Epoch %d: loss %.3f, train acc %.3f, test acc %.3f, in %.1f sec" % (
            (epoch + 1), train_loss/len(train_data), train_acc/len(train_data),
            valid_acc/len(valid_data), time.time()-tic))
# Out:
# Epoch 1: loss 0.779, train acc 0.719, test acc 0.819, in 8.2 sec
# Epoch 2: loss 0.474, train acc 0.826, test acc 0.847, in 8.4 sec
# Epoch 3: loss 0.414, train acc 0.847, test acc 0.857, in 8.3 sec
# Epoch 4: loss 0.385, train acc 0.858, test acc 0.859, in 8.2 sec
# Epoch 5: loss 0.362, train acc 0.869, test acc 0.873, in 8.4 sec
# Epoch 6: loss 0.342, train acc 0.875, test acc 0.875, in 8.3 sec
# Epoch 7: loss 0.331, train acc 0.879, test acc 0.874, in 8.2 sec
# Epoch 8: loss 0.316, train acc 0.883, test acc 0.868, in 8.3 sec
# Epoch 9: loss 0.306, train acc 0.887, test acc 0.882, in 8.4 sec
# Epoch 10: loss 0.296, train acc 0.891, test acc 0.882, in 8.3 sec
# Epoch 11: loss 0.287, train acc 0.895, test acc 0.883, in 8.2 sec
# Epoch 12: loss 0.279, train acc 0.897, test acc 0.883, in 8.3 sec
# Epoch 13: loss 0.274, train acc 0.899, test acc 0.888, in 8.4 sec
# Epoch 14: loss 0.265, train acc 0.902, test acc 0.884, in 8.7 sec
# ...

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
#
# 		pre code.dbs-code-sm {
# 			font-size: 1.2rem;
# 		}
#
# 		.dbs-scroll {
# 			height: 500px;
# 			overflow-y: scroll;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Testing our model</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# X, y = mnist_valid[:10]
# preds = []
# for x in X:
#     x = transformer(x).expand_dims(axis=0)
#     pred = net(x).argmax(axis=1)
#     preds.append(pred.astype('int32').asscalar())
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1 class="dbs-secondary">
# 								<strong>Visualising our results</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<pre>
# 								    <code class="language-python dbs-code">
# _, figs = plt.subplots(1, 10, figsize=(30, 50))
#
# for f, x, yi, pyi in zip(figs, X, y, preds):
#     f.imshow(x.reshape((28,28)).asnumpy())
#     ax = f.axes
#     ax.set_title("Label: %s \nPred: %s" % (text_labels[yi], text_labels[pyi]))
#     ax.title.set_fontsize(14)
#     ax.get_xaxis().set_visible(False)
#     ax.get_yaxis().set_visible(False)
# plt.show()
#                                     </code>
#                                 </pre>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...

# %%
X, y = mnist_valid[:10]
preds = []
for x in X:
    x = transformer(x).expand_dims(axis=0)
    pred = net(x).argmax(axis=1)
    preds.append(pred.astype('int32').asscalar())

# %%
_, figs = plt.subplots(1, 10, figsize=(30, 50))

for f, x, yi, pyi in zip(figs, X, y, preds):
    f.imshow(x.reshape((28,28)).asnumpy())
    ax = f.axes
    ax.set_title("Label: %s \nPred: %s" % (text_labels[yi], text_labels[pyi]))
    ax.title.set_fontsize(14)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# %%html
#
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"
# 			integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl"
# 			crossorigin="anonymous"
# 		></script>
# 		<script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# 		<script
# 			id="MathJax-script"
# 			async
# 			src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-mml-chtml.js"
# 		></script>
# 		<link
# 			href="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/themes/prism-okaidia.min.css"
# 			rel="stylesheet"
# 		/>
# 	</head>
# 	<style>
# 		body {
# 			width: 100%;
# 			height: 100%;
# 		}
#
# 		h1,
# 		h2,
# 		h3,
# 		h4,
# 		h5,
# 		h6,
# 		p,
# 		a,
# 		li,
# 		table {
# 			font-family: "Neucha", cursive;
# 		}
#
# 		h1 {
# 			font-size: 3.5rem;
# 		}
#
# 		h2 {
# 			font-size: 3rem;
# 		}
#
# 		h3 {
# 			font-size: 2.75rem;
# 		}
#
# 		h4 {
# 			font-size: 2.5rem;
# 		}
#
# 		h5 {
# 			font-size: 2.25rem;
# 		}
#
# 		h6 {
# 			font-size: 2rem;
# 		}
#
# 		p,
# 		a,
# 		li,
# 		table,
# 		span.math {
# 			font-size: 1.75rem;
# 		}
#
# 		span.math.md {
# 			font-size: 3rem;
# 		}
#
# 		span.math.lg {
# 			font-size: 5rem;
# 		}
#
# 		a {
# 			color: black;
# 		}
#
# 		table,
# 		tr,
# 		td,
# 		th {
# 			border: 1px solid #dfdfdf;
# 		}
#
# 		td,
# 		th {
# 			padding: 20px;
# 		}
#
# 		tr {
# 			transition: 0.5s;
# 		}
#
# 		thead tr {
# 			background-color: #cfcfcf;
# 		}
#
# 		tbody tr:nth-child(odd) {
# 			background-color: #efefef;
# 		}
#
# 		tbody tr:hover {
# 			background-color: #dfdfdf;
# 		}
#
# 		img {
# 			height: 500px;
# 		}
#
# 		.root {
# 			width: 98%;
# 			height: 800px;
# 		}
#
# 		.dbs-root {
# 			height: 800px;
# 		}
#
# 		.dbs-carousel-control {
# 			transition: 0.5s;
# 		}
#
# 		.dbs-carousel-control:hover {
# 			background-color: #efefef;
# 		}
#
# 		.dbs-carousel-indicators li {
# 			background-color: #dfdfdf;
# 			width: 10px;
# 			height: 10px;
# 			border-radius: 5px;
# 			margin-left: 2px;
# 			margin-right: 2px;
# 			cursor: pointer;
# 		}
#
# 		.dbs-carousel-indicators .active {
# 			background-color: #cfcfcf;
# 		}
#
# 		.dbs-container {
# 			display: flex;
# 			flex-direction: column;
# 			justify-content: center;
# 			align-items: center;
# 			width: 100%;
# 			height: 800px;
# 		}
#
# 		.dbs-standard {
# 			margin-top: 50px;
# 		}
#
# 		.dbs-separate {
# 			margin-top: 200px;
# 		}
#
# 		.dbs-subtitle {
# 			font-style: italic;
# 		}
#
# 		.dbs-secondary {
# 			color: grey;
# 		}
#
# 		.dbs-image {
# 			height: 500px;
# 		}
#
# 		.dbs-caption {
# 			margin-top: 20px;
# 		}
#
# 		.dbs-row {
# 			display: flex;
# 			flex-direction: row;
# 			align-items: center;
# 			justify-content: space-evenly;
# 		}
#
# 		.dbs-row.dbs-fluid {
# 			width: 75%;
# 		}
#
# 		.dbs-small-img {
# 			height: 150px;
# 		}
#
# 		#dbs-forex-table {
# 			font-size: 1.4rem;
# 			text-align: center;
# 		}
#
# 		#dbs-forex-table td,
# 		#dbs-forex-table th {
# 			padding: 10px;
# 			width: 200px;
# 		}
#
# 		#dbs-forex-table.dbs-skinny td,
# 		#dbs-forex-table.dbs-skinny th {
# 			width: 125px;
# 			padding: 7px;
# 		}
#
# 		#dbs-forex-table tr.dbs-sum {
# 			background-color: rgb(127, 199, 137);
# 		}
#
# 		pre code.dbs-code {
# 			font-size: 2rem;
# 		}
#
# 		pre code.dbs-code-sm {
# 			font-size: 1.2rem;
# 		}
#
# 		.dbs-scroll {
# 			height: 500px;
# 			overflow-y: scroll;
# 		}
# 	</style>
# 	<body>
# 		<div class="root">
# 			<div
# 				id="presentation"
# 				class="carousel slide"
# 				data-ride="carousel"
# 				data-interval="false"
# 			>
# 				<ol class="carousel-indicators dbs-carousel-indicators">
# 					<li
# 						data-target="#presentation"
# 						data-slide-to="0"
# 						class="active"
# 					></li>
# 					<li data-target="#presentation" data-slide-to="1"></li>
# 				</ol>
# 				<div class="carousel-inner dbs-root">
# 					<div class="carousel-item active">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>Resources</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<ol>
# 									<li>
# 										Coursera: Machine Learning by Andrew Ng
# 										(<a
# 											href="https://www.coursera.org/learn/machine-learning/home/welcome"
# 											>https://www.coursera.org/learn/machine-learning/home/welcome</a
# 										>)
# 									</li>
# 									<li>
# 										Google Machine Learning Crash Course (<a
# 											href="https://developers.google.com/machine-learning/crash-course/ml-intro"
# 											>https://developers.google.com/machine-learning/crash-course/ml-intro</a
# 										>)
# 									</li>
# 									<li>
# 										Washington University: Jeff Heaton (<a
# 											href="https://github.com/jeffheaton/t81_558_deep_learning"
# 											>https://github.com/jeffheaton/t81_558_deep_learning</a
# 										>)
# 									</li>
# 								</ol>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="carousel-item">
# 						<div class="dbs-container">
# 							<h1>
# 								<strong>The End</strong>
# 							</h1>
# 							<div class="dbs-standard">
# 								<img
# 									src="https://drive.google.com/uc?id=105rnTXz1r8E-R74IJ7HkaTaZnKEY2wCC"
# 									alt="Thank you"
# 								/>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<a
# 					class="carousel-control-prev dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="prev"
# 				>
# 					<span
# 						class="carousel-control-prev-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Previous</span>
# 				</a>
# 				<a
# 					class="carousel-control-next dbs-carousel-control"
# 					href="#presentation"
# 					role="button"
# 					data-slide="next"
# 				>
# 					<span
# 						class="carousel-control-next-icon"
# 						aria-hidden="true"
# 					></span>
# 					<span class="sr-only">Next</span>
# 				</a>
# 			</div>
# 		</div>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/components/prism-core.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/prism/1.20.0/plugins/autoloader/prism-autoloader.min.js"></script>
# 	</body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="fen">
# 	<head>
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0" />
# 		<title>Introduction to Machine Learning on Google Colab</title>
# 		<link
# 			rel="stylesheet"
# 			href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css"
# 			integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm"
# 			crossorigin="anonymous"
# 		/>
# 		<link
# 			href="https://fonts.googleapis.com/css2?family=Neucha&display=swap"
# 			rel="stylesheet"
# 		/>
# 		<script
# 			src="https://code.jquery.com/jquery-3.2.1.slim.min.js"
# 			integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN"
# 			crossorigin="anonymous"
# 		></script>
# 		<script
# 			src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"
# 			integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q"
# 			crossorigin="anonymous"
# ...
